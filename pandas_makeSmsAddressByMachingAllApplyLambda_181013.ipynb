# %%
# 판다스 임포트 #pandas
import pandas as pd
from pandas import Series, DataFrame
import pdb

# %%
# 불러올 파일 지정하기 #pandas
inputFile1 = 'pandas_googleAddress_181012.csv'

# %%
# 불러올 파일 지정하기 #pandas
inputFile2 = 'pandas_matchSms.csv'

# %%
# CSV파일을 df(데이터 프레임)로 부르기 #pandas
dfFrom = pd.read_csv(inputFile1, encoding='utf-8', index_col=0)

# %%
# 열 이름 바꾸기 #느낀점 #pandas
dfFrom.columns = ['name', 'phone', 'otherPhone', 'note', 'email', 'otherEmail']

# %%
# CSV파일을 df(데이터 프레임)로 부르기 #pandas
dfTo = pd.read_csv(inputFile2, encoding='utf-8', index_col=0)

dfTo.columns = ['name','phone']

# 데이터 프레임 초기화하여 반영하기
dfTo.reset_index(drop=True, inplace=True)

# %%
# 해결이 안됨 사용하지 말것.
def lookupPhone(col):
    for row in dfTo.itertuples():
        for i in col:
            if i in row[1]:
                return row[2]
            else:
                return 'n/a'
        
dfName['Phone1'] = dfName['name'].apply(lookupPhone)

# %%
# 하나의 데이터 프레임의 값을 읽어서 다른 데이터 프레임과 비교해서 일치하는 값이 있는경우 데이터를 저장 #pandas #느낀점
dfTo['phone'] = dfTo.name.apply(lambda x : dfFrom.phone[dfFrom.name.str.contains(x)].sum(),1)
dfTo
# Out:
#      name                     phone                     Phone
# 0   인사문대호                         0                         0
# 1   인사최재운                         0                         0
# 2    청안선옥             010-3667-0560             010-3667-0560
# 3    냉장성환             010-3594-9508             010-3594-9508
# 4   동문권선미                         0                         0
# 5   인사현서희                         0                         0
# 6    청한호림             010-5696-1309             010-5696-1309
# 7   인사김동현                         0                         0
# 8    청김동목             010-6264-7081             010-6264-7081
# 9   동문안희승                         0                         0
# 10   서김은경                         0                         0
# 11   후임종필                         0                         0
# 12   서김민자                         0                         0
# 13  인사김래은                         0                         0
# 14  인사황대연                         0                         0
# 15   청심봉섭             010-3389-5466             010-3389-5466
# 16   청최정석                1089485127                1089485127
# 17   청박정훈                         0                         0
# 18   청박성실                         0                         0
# 19   청김국남                         0                         0
# 20   청조병훈             010-4310-0195             010-4310-0195
# 21   친장재은                         0                         0
# 22  인사이창규             010-6272-0200             010-6272-0200
# 23  인사이민석             010-8777-1157             010-8777-1157
# 24  인사이승제                         0                         0
# 25   청김영훈             010-9479-7442             010-9479-7442
# 26   청오재민             010-8764-5241             010-8764-5241
# 27   형박명래             010-4690-1270             010-4690-1270
# 28   형신주영  8.21046E+11010-4643-1397  8.21046E+11010-4643-1397
# 29   동김민석                         0                         0
# 30   동류재현             010-3374-9709             010-3374-9709
# 31   동박귀선                1053317216                1053317216
# 32   동최준성              011-485-1345              011-485-1345
# 33   동안재원             010-8652-6315             010-8652-6315
# 34   청김세영             010-3733-9516             010-3733-9516
# 35   청성영경             010-4318-8883             010-4318-8883
# 36  인사박영배             010-5278-8224             010-5278-8224
# 37  인사김창현                         0                         0
# 38  인사이문구             010-9075-0637             010-9075-0637
# 39  인사정승헌                         0                         0
# 40  인사이병선             010-2630-9627             010-2630-9627
# 41   서김승렬                         0                         0
# 42     석훈             010-7358-5735             010-7358-5735
# 43     성환             010-3594-9508             010-3594-9508
# 44    김승렬                         0                         0
# 45    이문구             010-9075-0637             010-9075-0637
# 46    박철규             010-8799-8107             010-8799-8107

# %%
# 칼럼 삭제하기
dfTo.drop('Phone', axis=1)
# Out:
#      name                     phone
# 0   인사문대호                         0
# 1   인사최재운                         0
# 2    청안선옥             010-3667-0560
# 3    냉장성환             010-3594-9508
# 4   동문권선미                         0
# 5   인사현서희                         0
# 6    청한호림             010-5696-1309
# 7   인사김동현                         0
# 8    청김동목             010-6264-7081
# 9   동문안희승                         0
# 10   서김은경                         0
# 11   후임종필                         0
# 12   서김민자                         0
# 13  인사김래은                         0
# 14  인사황대연                         0
# 15   청심봉섭             010-3389-5466
# 16   청최정석                1089485127
# 17   청박정훈                         0
# 18   청박성실                         0
# 19   청김국남                         0
# 20   청조병훈             010-4310-0195
# 21   친장재은                         0
# 22  인사이창규             010-6272-0200
# 23  인사이민석             010-8777-1157
# 24  인사이승제                         0
# 25   청김영훈             010-9479-7442
# 26   청오재민             010-8764-5241
# 27   형박명래             010-4690-1270
# 28   형신주영  8.21046E+11010-4643-1397
# 29   동김민석                         0
# 30   동류재현             010-3374-9709
# 31   동박귀선                1053317216
# 32   동최준성              011-485-1345
# 33   동안재원             010-8652-6315
# 34   청김세영             010-3733-9516
# 35   청성영경             010-4318-8883
# 36  인사박영배             010-5278-8224
# 37  인사김창현                         0
# 38  인사이문구             010-9075-0637
# 39  인사정승헌                         0
# 40  인사이병선             010-2630-9627
# 41   서김승렬                         0
# 42     석훈             010-7358-5735
# 43     성환             010-3594-9508
# 44    김승렬                         0
# 45    이문구             010-9075-0637
# 46    박철규             010-8799-8107

# %%
# 행을 추가하는 방법 #느낀점 #pandas
dfTo.loc[43] = ['성환','','']
dfTo
# Out:
#      name phone          Phone
# 0   인사문대호   NaN            n/a
# 1   인사최재운   NaN            n/a
# 2    청안선옥   NaN            n/a
# 3    냉장성환   NaN            n/a
# 4   동문권선미   NaN            n/a
# 5   인사현서희   NaN            n/a
# 6    청한호림   NaN            n/a
# 7   인사김동현   NaN            n/a
# 8    청김동목   NaN            n/a
# 9   동문안희승   NaN            n/a
# 10   서김은경   NaN            n/a
# 11   후임종필   NaN            n/a
# 12   서김민자   NaN            n/a
# 13  인사김래은   NaN            n/a
# 14  인사황대연   NaN            n/a
# 15   청심봉섭   NaN            n/a
# 16   청최정석   NaN            n/a
# 17   청박정훈   NaN            n/a
# 18   청박성실   NaN            n/a
# 19   청김국남   NaN            n/a
# 20   청조병훈   NaN            n/a
# 21   친장재은   NaN            n/a
# 22  인사이창규   NaN            n/a
# 23  인사이민석   NaN            n/a
# 24  인사이승제   NaN            n/a
# 25   청김영훈   NaN            n/a
# 26   청오재민   NaN            n/a
# 27   형박명래   NaN            n/a
# 28   형신주영   NaN            n/a
# 29   동김민석   NaN            n/a
# 30   동류재현   NaN            n/a
# 31   동박귀선   NaN            n/a
# 32   동최준성   NaN            n/a
# 33   동안재원   NaN            n/a
# 34   청김세영   NaN            n/a
# 35   청성영경   NaN            n/a
# 36  인사박영배   NaN            n/a
# 37  인사김창현   NaN            n/a
# 38  인사이문구   NaN            n/a
# 39  인사정승헌   NaN            n/a
# 40  인사이병선   NaN            n/a
# 41   서김승렬   NaN            n/a
# 42     석훈        010-7358-5735
# 43     성환
# 44    김승렬                  n/a
# 45    이문구                  n/a
# 46    박철규                  n/a

# %%
# 데이터 프레임에서 열의 값을 원하는 만큼만 슬라이싱
b = []
for i in dfTo.name:
    b.append(i[-3:]) #뒤에서 세글자 인사문대호 → 문대호
    
dfName = pd.DataFrame(b)
dfName
# Out:
#       0
# 0   문대호
# 1   최재운
# 2   안선옥
# 3   장성환
# 4   권선미
# 5   현서희
# 6   한호림
# 7   김동현
# 8   김동목
# 9   안희승
# 10  김은경
# 11  임종필
# 12  김민자
# 13  김래은
# 14  황대연
# 15  심봉섭
# 16  최정석
# 17  박정훈
# 18  박성실
# 19  김국남
# 20  조병훈
# 21  장재은
# 22  이창규
# 23  이민석
# 24  이승제
# 25  김영훈
# 26  오재민
# 27  박명래
# 28  신주영
# 29  김민석
# 30  류재현
# 31  박귀선
# 32  최준성
# 33  안재원
# 34  김세영
# 35  성영경
# 36  박영배
# 37  김창현
# 38  이문구
# 39  정승헌
# 40  이병선
# 41  김승렬
# 42   석훈
# 43   성환
# 44  김승렬
# 45  이문구
# 46  박철규

# %%
# 칼럼 추가하기 #느낀점 #pandas
dfName['phone'] = ''
dfName
# Out:
#    name phone
# 0   문대호
# 1   최재운
# 2   안선옥
# 3   장성환
# 4   권선미
# 5   현서희
# 6   한호림
# 7   김동현
# 8   김동목
# 9   안희승
# 10  김은경
# 11  임종필
# 12  김민자
# 13  김래은
# 14  황대연
# 15  심봉섭
# 16  최정석
# 17  박정훈
# 18  박성실
# 19  김국남
# 20  조병훈
# 21  장재은
# 22  이창규
# 23  이민석
# 24  이승제
# 25  김영훈
# 26  오재민
# 27  박명래
# 28  신주영
# 29  김민석
# 30  류재현
# 31  박귀선
# 32  최준성
# 33  안재원
# 34  김세영
# 35  성영경
# 36  박영배
# 37  김창현
# 38  이문구
# 39  정승헌
# 40  이병선
# 41  김승렬
# 42   석훈
# 43   성환
# 44  김승렬
# 45  이문구
# 46  박철규
