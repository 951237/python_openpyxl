# %%
# 판다스 임포트 #pandas
import pandas as pd
from pandas import Series, DataFrame
import pdb

# %%
df = pd.read_clipboard(header = None)
df.columns
# Out:
# Int64Index([0, 1], dtype='int64')

# %%
# 행 칼럼 이름 바꾸기 #pandas #기초 #느낀점
df.columns = ['path', 'filename']
df
# Out:
#                                                  path   filename
# 0    /Volumes/SeconBay/OneDrive/★만화/★킹덤/킹덤  541화.zip
# 1    /Volumes/SeconBay/OneDrive/★만화/★킹덤/킹덤  542화.zip
# 2    /Volumes/SeconBay/OneDrive/★만화/★킹덤/킹덤  543화.zip
# 3    /Volumes/SeconBay/OneDrive/★만화/★킹덤/킹덤  544화.zip
# 4    /Volumes/SeconBay/OneDrive/★만화/★킹덤/킹덤  545화.zip
# 5    /Volumes/SeconBay/OneDrive/★만화/★킹덤/킹덤    546.zip
# 6    /Volumes/SeconBay/OneDrive/★만화/★킹덤/킹덤    547.zip
# 7    /Volumes/SeconBay/OneDrive/★만화/★킹덤/킹덤    548.zip
# 8    /Volumes/SeconBay/OneDrive/★만화/★킹덤/킹덤  549화.zip
# 9    /Volumes/SeconBay/OneDrive/★만화/★킹덤/킹덤  550화.zip
# 10   /Volumes/SeconBay/OneDrive/★만화/★킹덤/킹덤  551화.zip
# 11   /Volumes/SeconBay/OneDrive/★만화/★킹덤/킹덤  552화.zip
# 12   /Volumes/SeconBay/OneDrive/★만화/★킹덤/킹덤  553화.zip
# 13   /Volumes/SeconBay/OneDrive/★만화/★킹덤/킹덤  554화.zip
# 14   /Volumes/SeconBay/OneDrive/★만화/★킹덤/킹덤  555화.zip
# 15   /Volumes/SeconBay/OneDrive/★만화/★킹덤/킹덤  556화.zip
# ...

# %%
# 정렬하기 
df.sort_values(['filename'])
# Out:
#                                                  path   filename
# 0    /Volumes/SeconBay/OneDrive/★만화/★킹덤/킹덤  541화.zip
# 1    /Volumes/SeconBay/OneDrive/★만화/★킹덤/킹덤  542화.zip
# 2    /Volumes/SeconBay/OneDrive/★만화/★킹덤/킹덤  543화.zip
# 3    /Volumes/SeconBay/OneDrive/★만화/★킹덤/킹덤  544화.zip
# 4    /Volumes/SeconBay/OneDrive/★만화/★킹덤/킹덤  545화.zip
# 5    /Volumes/SeconBay/OneDrive/★만화/★킹덤/킹덤    546.zip
# 6    /Volumes/SeconBay/OneDrive/★만화/★킹덤/킹덤    547.zip
# 7    /Volumes/SeconBay/OneDrive/★만화/★킹덤/킹덤    548.zip
# 8    /Volumes/SeconBay/OneDrive/★만화/★킹덤/킹덤  549화.zip
# 9    /Volumes/SeconBay/OneDrive/★만화/★킹덤/킹덤  550화.zip
# 10   /Volumes/SeconBay/OneDrive/★만화/★킹덤/킹덤  551화.zip
# 11   /Volumes/SeconBay/OneDrive/★만화/★킹덤/킹덤  552화.zip
# 12   /Volumes/SeconBay/OneDrive/★만화/★킹덤/킹덤  553화.zip
# 13   /Volumes/SeconBay/OneDrive/★만화/★킹덤/킹덤  554화.zip
# 14   /Volumes/SeconBay/OneDrive/★만화/★킹덤/킹덤  555화.zip
# 15   /Volumes/SeconBay/OneDrive/★만화/★킹덤/킹덤  556화.zip
# ...
