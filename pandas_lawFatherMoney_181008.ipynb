# %%
# 판다스 임포트
import numpy as np
import pandas as pd
from pandas import Series, DataFrame
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# 불러올 파일 지정하기
inputFile = 'lawFather.csv'

# %%
# CSV파일을 df(데이터 프레임)로 부르기
df = pd.read_csv(inputFile)

# %%
# 데이터 프레임에서 소속칼럼에서 특정 문자를 포함한 데이터 인덱싱하기
kangSchool = df.loc[(df['소속'].str.contains('안산대월초'))]

# %%
# 데이터 프레임에서 소속칼럼에서 특정 문자를 포함한 데이터 인덱싱하기
choiSchool = df.loc[(df['소속'].str.contains('화현초'))]

# %%
# 데이터 프레임에서 소속칼럼에서 특정 문자를 포함한 데이터 인덱싱하기
seokSchool = df.loc[(df['소속'].str.contains('학현초'))]

# %%
# 안산대월초 부의 금액
kangSchool.금액.sum()
# Out:
# 267

# %%
# 화현초 부의금액
choiSchool.금액.sum()
# Out:
# 83

# %%
# 학현초 부의 금액
seokSchool.금액.sum()
# Out:
# 163

# %%
# CSV파일로 저장하기
outFile.to_csv('pandas_lawFile_181008.csv')

# %%
# 칼럼의 값을 필터링 하기
seokAll = df[ df['코드'] == 3 ]

# %%
# 칼럼의 값을 합산하기
seokAll.금액.sum()
# Out:
# 308

# %%
# 칼럼 추출하여 저장하기
seokAll = seokAll[ [ '소속', '이름','금액' ]]

# %%
# 칼럼의 갯수 카운트 하기
seokAll.이름.count()
# Out:
# 58

# %%
# 값으로 정렬하기 
df.sort_values('소속')
# Out:
#       구분      소속       이름  금액    코드
# 0      3       -      김문숙   5   NaN
# 14   291       -      위영숙  20   NaN
# 13   262       -      윤설령  10   NaN
# 12   234       -      민영애   5   NaN
# 11   233       -      노영균   5   NaN
# 10   204       -      황원선   5   NaN
# 9    188       -      윤재중   5   NaN
# 15   292       -      곽일순  20   NaN
# 8    187       -      정광석   5   NaN
# 6    173       -      박종선   5   NaN
# 5    169       -      허재화   5   NaN
# 4    151       -      문대호   5  10.0
# 3    146       -      박종한   5   NaN
# 2     46       -      조성삼   5   NaN
# 1     11       -      김정훈   5   NaN
# 7    181       -      남무환   5   NaN
# 16   295       -      이길구  30   NaN
# 17   232     개군초       박정  10   NaN
# 18    63  경기도교육청      최재운   5  10.0
# 19   201  경기도교육청      장동진   5   NaN
# 20   190     경수초      이기주   5   NaN
# 21   243     경일초      조주은  10   NaN
# 22   303     고잔초      안선옥   5   3.0
# 23    75  관산초병설유      송이현   5   NaN
# 25   294    광주가족  강수진 이신선  20   NaN
# ...

# %%
# 값으로 정렬하기 
df.sort_values('소속', ascending=False)
# Out:
#       구분      소속       이름  금액    코드
# 302  155     효덕초      천병석   5   NaN
# 293   86     화현초      허승희   5   2.0
# 285   78     화현초      김혜경   5   2.0
# 286   79     화현초      이배영   5   2.0
# 287   80     화현초      백은선   5   2.0
# 288   81     화현초      전주은   5   2.0
# 289   82     화현초      김경애   5   2.0
# 290   83     화현초      이한별   5   2.0
# 291   84     화현초      최성관   5   2.0
# 292   85     화현초      김영세   5   2.0
# 294  209     화현초      힐러리   3   2.0
# 295  270     화현초      이병석  10   2.0
# 296  280     화현초      친화회  10   2.0
# 297  282     화현초      신현경   3   2.0
# 298  283     화현초      박남미   3   2.0
# 299  284     화현초       한신   3   2.0
# 300  285     화현초      황윤정   3   2.0
# 301  286     화현초      김순심   3   2.0
# 284  207     화정초      송미화   5   NaN
# 283  236   화성동양초      이순진  10   NaN
# 282  161   화성남양초      김승렬   5   3.0
# 280  196     화랑초      이종원   5   NaN
# 279   30     화랑초      주형춘   5   NaN
# 281  259     화랑초      조장호  10   NaN
# 278  179     호원초      박형식   5   NaN
# ...

# %%
# 값으로 정렬하기 1순위 = 소속, 2순위 = 이름
df.sort_values(by=['소속', '이름'])
# Out:
#       구분      소속       이름  금액    코드
# 15   292       -      곽일순  20   NaN
# 0      3       -      김문숙   5   NaN
# 1     11       -      김정훈   5   NaN
# 7    181       -      남무환   5   NaN
# 11   233       -      노영균   5   NaN
# 4    151       -      문대호   5  10.0
# 12   234       -      민영애   5   NaN
# 6    173       -      박종선   5   NaN
# 3    146       -      박종한   5   NaN
# 14   291       -      위영숙  20   NaN
# 13   262       -      윤설령  10   NaN
# 9    188       -      윤재중   5   NaN
# 16   295       -      이길구  30   NaN
# 8    187       -      정광석   5   NaN
# 2     46       -      조성삼   5   NaN
# 5    169       -      허재화   5   NaN
# 10   204       -      황원선   5   NaN
# 17   232     개군초       박정  10   NaN
# 19   201  경기도교육청      장동진   5   NaN
# 18    63  경기도교육청      최재운   5  10.0
# 20   190     경수초      이기주   5   NaN
# 21   243     경일초      조주은  10   NaN
# 22   303     고잔초      안선옥   5   3.0
# 23    75  관산초병설유      송이현   5   NaN
# 26   297    광주가족   강갑연(?)  30   NaN
# ...

# %%
df2 = df2.sort_values(by=['소속', '이름'])

# %%
DataFrame(df2)
# Out:
#          소속       이름  금액    코드
# 15        -      곽일순  20   NaN
# 0         -      김문숙   5   NaN
# 1         -      김정훈   5   NaN
# 7         -      남무환   5   NaN
# 11        -      노영균   5   NaN
# 4         -      문대호   5  10.0
# 12        -      민영애   5   NaN
# 6         -      박종선   5   NaN
# 3         -      박종한   5   NaN
# 14        -      위영숙  20   NaN
# 13        -      윤설령  10   NaN
# 9         -      윤재중   5   NaN
# 16        -      이길구  30   NaN
# 8         -      정광석   5   NaN
# 2         -      조성삼   5   NaN
# 5         -      허재화   5   NaN
# 10        -      황원선   5   NaN
# 17      개군초       박정  10   NaN
# 19   경기도교육청      장동진   5   NaN
# 18   경기도교육청      최재운   5  10.0
# 20      경수초      이기주   5   NaN
# 21      경일초      조주은  10   NaN
# 22      고잔초      안선옥   5   3.0
# 23   관산초병설유      송이현   5   NaN
# 26     광주가족   강갑연(?)  30   NaN
# 25     광주가족  강수진 이신선  20   NaN
# 24     광주가족  강은숙 김장수  20   NaN
# 27      교육부      장경훈   5   NaN
# 28    군포수리초      정명숙   5   NaN
# ...

# %%
# 값의 숫자를 세어줌
df2['소속'].value_counts()
# Out:
# 안산대월초          49
# 학현초            31
# 춘교 실과98        22
# -              17
# 화현초            17
# 초지초            16
# 정지초             8
# 쌍용차             6
# 외가              6
# 안산청석초           5
# 인교 미술95         5
# 한들유치원           4
# 선부초             4
# 예천가족            4
# 원일초             4
# 본원초             4
# 안산양지초           4
# 안산석수초           3
# 선일초             3
# 처형친구            3
# 광주가족            3
# 화랑초             3
# 영민친구            3
# 신길초             3
# 반월초             3
# 왕배초             2
# 별망초             2
# 본오초             2
# 두드림             2
# 성안초             2
#                ..
# 개군초             1
# 와동초             1
# 교육부             1
# 안산지원청 경영지원과     1
# 인교 미술91         1
# 석수초             1
# 성포성당            1
# 전 안산대월초         1
# 경일초             1
# 죽전초             1
# 제일초             1
# 효덕초             1
# 시흥정왕초           1
# 대부초             1
# 예천친구            1
# 해솔초             1
# 평택초             1
# 양지초             1
# 관산초병설유          1
# ...

# %%
# 소속의 중복없는 값을 뽑아내기
df2['소속'].unique()
# Out:
# array(['-', '개군초', '경기도교육청', '경수초', '경일초', '고잔초', '관산초병설유', '광주가족', '교육부',
#        '군포수리초', '냉정초', '대부초', '덕성초', '두드림', '반월초', '백암초', '별망초', '본오초',
#        '본원초', '봉담초', '석수초', '석호초', '선부초', '선일초', '성안초', '성포성당', '성포성당 ',
#        '슬기초', '시랑초', '시흥교육지원청', '시흥연성중', '시흥정왕초', '시흥조남초', '시흥중', '시흥진말초',
#        '신길초', '쌍용차', '안산광덕초', '안산대월초', '안산부곡초', '안산서초', '안산석수초', '안산양지초',
#        '안산지원청 경영지원과', '안산창촌초', '안산청석초', '안산호원초', '안양관악초', '양지초', '영민친구',
#        '예천가족', '예천친구', '옛선부초', '와동초', '왕배초', '외가', '용인신흥초', '원곡초', '원일초',
#        '인교 미술91', '인교 미술93', '인교 미술95', '전 선부초', '전 안산대월초', '정재초', '정지초',
#        '정평초', '제일초', '죽전초', '중앙초', '처형친구', '초지초', '초지초병설', '춘교 실과98',
#        '파주삼성초', '평택초', '포천교육지원청', '학현초', '한들유치원', '해솔초', '현암초', '호동초',
#        '호원초', '화랑초', '화성남양초', '화성동양초', '화정초', '화현초', '효덕초'], dtype=object)

# %%
# 소속이 초지초인 값만 뽑아내기
df2.loc[ df2['소속'].isin( [ '초지초' ] ), : ]
# Out:
#       소속   이름  금액  코드
# 212  초지초  강빛나   3 NaN
# 202  초지초  김미영   5 NaN
# 201  초지초  김종순   5 NaN
# 198  초지초  김지희   5 NaN
# 210  초지초  남은경   3 NaN
# 206  초지초  박미영   5 NaN
# 205  초지초   송희   5 NaN
# 199  초지초  우지원   5 NaN
# 197  초지초  이선교   5 NaN
# 200  초지초  이성경   5 NaN
# 208  초지초  이정수   5 NaN
# 209  초지초  이진욱   5 NaN
# 204  초지초  임봉애   5 NaN
# 203  초지초  임호선   5 NaN
# 207  초지초  하은실   5 NaN
# 211  초지초  홍세희   3 NaN

# %%
# 소속이 초지초인 값만 뽑아내기
df2.loc[ df2['소속'].isin( [ '초지초', '화현초', '정지초' ] ), : ]
# Out:
# 소속    41
# 이름    41
# 금액    41
# 코드    17
# dtype: int64

# %%
# 정렬후 인덱스 값을 초기화 하기
df3.reindex(range(303))
# Out:
#          소속       이름  금액    코드
# 0         -      김문숙   5   NaN
# 1         -      김정훈   5   NaN
# 2         -      조성삼   5   NaN
# 3         -      박종한   5   NaN
# 4         -      문대호   5  10.0
# 5         -      허재화   5   NaN
# 6         -      박종선   5   NaN
# 7         -      남무환   5   NaN
# 8         -      정광석   5   NaN
# 9         -      윤재중   5   NaN
# 10        -      황원선   5   NaN
# 11        -      노영균   5   NaN
# 12        -      민영애   5   NaN
# 13        -      윤설령  10   NaN
# 14        -      위영숙  20   NaN
# 15        -      곽일순  20   NaN
# 16        -      이길구  30   NaN
# 17      개군초       박정  10   NaN
# 18   경기도교육청      최재운   5  10.0
# 19   경기도교육청      장동진   5   NaN
# 20      경수초      이기주   5   NaN
# 21      경일초      조주은  10   NaN
# 22      고잔초      안선옥   5   3.0
# 23   관산초병설유      송이현   5   NaN
# 24     광주가족  강은숙 김장수  20   NaN
# 25     광주가족  강수진 이신선  20   NaN
# 26     광주가족   강갑연(?)  30   NaN
# 27      교육부      장경훈   5   NaN
# 28    군포수리초      정명숙   5   NaN
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 303 entries, 0 to 302
# Data columns (total 5 columns):
# 구분    303 non-null int64
# 소속    303 non-null object
# 이름    303 non-null object
# 금액    303 non-null int64
# 코드    98 non-null float64
# dtypes: float64(1), int64(2), object(2)
# memory usage: 11.9+ KB

# %%
#데이터 프레임에서 원하는 칼럼을 추출하거나, 칼럼 순서 정하기 
df = df[[ '소속', '이름', '금액', '코드']]

# %%
df
# Out:
#          소속       이름  금액    코드
# 0         -      김문숙   5   NaN
# 1         -      김정훈   5   NaN
# 2         -      조성삼   5   NaN
# 3         -      박종한   5   NaN
# 4         -      문대호   5  10.0
# 5         -      허재화   5   NaN
# 6         -      박종선   5   NaN
# 7         -      남무환   5   NaN
# 8         -      정광석   5   NaN
# 9         -      윤재중   5   NaN
# 10        -      황원선   5   NaN
# 11        -      노영균   5   NaN
# 12        -      민영애   5   NaN
# 13        -      윤설령  10   NaN
# 14        -      위영숙  20   NaN
# 15        -      곽일순  20   NaN
# 16        -      이길구  30   NaN
# 17      개군초       박정  10   NaN
# 18   경기도교육청      최재운   5  10.0
# 19   경기도교육청      장동진   5   NaN
# 20      경수초      이기주   5   NaN
# 21      경일초      조주은  10   NaN
# 22      고잔초      안선옥   5   3.0
# 23   관산초병설유      송이현   5   NaN
# 24     광주가족  강은숙 김장수  20   NaN
# 25     광주가족  강수진 이신선  20   NaN
# 26     광주가족   강갑연(?)  30   NaN
# 27      교육부      장경훈   5   NaN
# 28    군포수리초      정명숙   5   NaN
# ...

# %%
#데이터 타입 체크하기
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 303 entries, 0 to 302
# Data columns (total 4 columns):
# 소속    303 non-null object
# 이름    303 non-null object
# 금액    303 non-null int64
# 코드    98 non-null float64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 9.5+ KB

# %%
#데이터 null값 체크하기
df.isnull().sum()
# Out:
# 소속      0
# 이름      0
# 금액      0
# 코드    205
# dtype: int64

# %%
# 빈셀의 값을 더해서 인덱싱 다시 하기
missing_df = df.isnull().sum().reset_index()

# %%
missing_df
# Out:
#   index    0
# 0    소속    0
# 1    이름    0
# 2    금액    0
# 3    코드  205

# %%
# missing_df 데이터 프레임 칼럼 이름 정하기
missing_df.columns = ['column', 'count']

# %%
missing_df
# Out:
#   column  count
# 0     소속      0
# 1     이름      0
# 2     금액      0
# 3     코드    205

# %%
# missing_df 데이터 프레임의 비율 칼럼 추가하기
missing_df['ratio'] = missing_df['count'] / df.shape[0]

# %%
# missing_df 데이터 프레임에서 빈셀이 있는 행만 추출하기
missing_df.loc[ missing_df['ratio'] != 0 ]
# Out:
#   column  count     ratio
# 3     코드    205  0.676568

# %%
#금액별로 그래프 그리기
df['금액'].value_counts().plot(kind='bar')

# %%
category_feachure = [col for col in df.columns if df[col].dtypes == 'object']

# %%
category_feachure
# Out:
# ['소속', '이름']

# %%
# todo merged_processed[col]이 의미하는 것음 무엇일까? 
for col in category_feachure:
    merged_processed[col].value_counts().plot(kind='bar')
    plt.title(col)
    plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-8c395d86a134> in <module>()
#       1 for col in category_feachure:
# ----> 2     merged_processed[col].value_counts().plot(kind='bar')
#       3     plt.title(col)
#       4     plt.show()
#
# NameError: name 'merged_processed' is not defined

# %%
seokSchool.reindex(np.)
# Out:
#       구분   소속           이름  금액   코드
# 239    7  학현초          최종철   5  3.0
# 240   50  학현초          김승희   5  3.0
# 241  119  학현초          김소희   5  3.0
# 242  120  학현초          안태우   5  3.0
# 243  121  학현초          유수정   5  3.0
# 244  122  학현초          이민호   5  3.0
# 245  123  학현초          김정혜   5  3.0
# 246  124  학현초          윤승희   5  3.0
# 247  125  학현초          이정화   5  3.0
# 248  126  학현초          김문희   5  3.0
# 249  127  학현초          남현화   5  3.0
# 250  128  학현초          김인숙   5  3.0
# 251  129  학현초          행정실   5  3.0
# 252  130  학현초          우서경   5  3.0
# 253  131  학현초          류지영   5  3.0
# 254  132  학현초          정은홍   5  3.0
# 255  133  학현초          류창한   5  3.0
# 256  134  학현초          김정연   5  3.0
# 257  135  학현초          유정임   5  3.0
# 258  136  학현초          정나라   5  3.0
# 259  137  학현초          정현숙   5  3.0
# 260  138  학현초          이다영   5  3.0
# 261  139  학현초          김수연   5  3.0
# 262  210  학현초          이희두   3  3.0
# 263  211  학현초          이경란   3  3.0
# ...

# %%
m_df = seokSchool.groupby( [ '금액', '소속' ] )['소속'].count().unstack('소속')

# %%
m_df.plot(kind='bar', figsize=(20,10))
plt.title('money')
plt.show()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 303 entries, 0 to 302
# Data columns (total 4 columns):
# 소속    303 non-null object
# 이름    303 non-null object
# 금액    303 non-null int64
# 코드    98 non-null float64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 9.5+ KB

# %%
seokSchool = seokSchool[ ['소속', '이름', '금액'] ]

# %%
seokSchool['이름'].value_counts()
# Out:
# 윤승희            1
# 김수연            1
# 행정실            1
# 정은홍            1
# 최종철            1
# 김문희            1
# 이민호            1
# 김제화            1
# 류창한            1
# 김인숙            1
# 이미리            1
# 친목회            1
# 류지영            1
# 박현경            1
# 이정화            1
# 신지원            1
# 정나라            1
# 김정혜            1
# 이다영            1
# 김정연            1
# 남현화            1
# 이희두            1
# 김승희            1
# 김소희            1
# 김을랑 박은실 최영미    1
# 안태우            1
# 이경란            1
# 정현숙            1
# 유정임            1
# 유수정            1
# 우서경            1
# Name: 이름, dtype: int64

# %%
seokSchool.reindex(range(31))
# Out:
#     구분   소속   이름  금액  코드
# 0  NaN  NaN  NaN NaN NaN
# 1  NaN  NaN  NaN NaN NaN
# 2  NaN  NaN  NaN NaN NaN
# 3  NaN  NaN  NaN NaN NaN
# 4  NaN  NaN  NaN NaN NaN
# 5  NaN  NaN  NaN NaN NaN
# 6  NaN  NaN  NaN NaN NaN
# 7  NaN  NaN  NaN NaN NaN
# 8  NaN  NaN  NaN NaN NaN
# 9  NaN  NaN  NaN NaN NaN
# 10 NaN  NaN  NaN NaN NaN
# 11 NaN  NaN  NaN NaN NaN
# 12 NaN  NaN  NaN NaN NaN
# 13 NaN  NaN  NaN NaN NaN
# 14 NaN  NaN  NaN NaN NaN
# 15 NaN  NaN  NaN NaN NaN
# 16 NaN  NaN  NaN NaN NaN
# 17 NaN  NaN  NaN NaN NaN
# 18 NaN  NaN  NaN NaN NaN
# 19 NaN  NaN  NaN NaN NaN
# 20 NaN  NaN  NaN NaN NaN
# 21 NaN  NaN  NaN NaN NaN
# 22 NaN  NaN  NaN NaN NaN
# 23 NaN  NaN  NaN NaN NaN
# 24 NaN  NaN  NaN NaN NaN
# 25 NaN  NaN  NaN NaN NaN
# 26 NaN  NaN  NaN NaN NaN
# 27 NaN  NaN  NaN NaN NaN
# 28 NaN  NaN  NaN NaN NaN
# 29 NaN  NaN  NaN NaN NaN
# 30 NaN  NaN  NaN NaN NaN

# %%
# 정렬후 인덱스 값을 초기화 하기
df3.reindex(range(303))
# Out:
#          소속       이름  금액    코드
# 0         -      김문숙   5   NaN
# 1         -      김정훈   5   NaN
# 2         -      조성삼   5   NaN
# 3         -      박종한   5   NaN
# 4         -      문대호   5  10.0
# 5         -      허재화   5   NaN
# 6         -      박종선   5   NaN
# 7         -      남무환   5   NaN
# 8         -      정광석   5   NaN
# 9         -      윤재중   5   NaN
# 10        -      황원선   5   NaN
# 11        -      노영균   5   NaN
# 12        -      민영애   5   NaN
# 13        -      윤설령  10   NaN
# 14        -      위영숙  20   NaN
# 15        -      곽일순  20   NaN
# 16        -      이길구  30   NaN
# 17      개군초       박정  10   NaN
# 18   경기도교육청      최재운   5  10.0
# 19   경기도교육청      장동진   5   NaN
# 20      경수초      이기주   5   NaN
# 21      경일초      조주은  10   NaN
# 22      고잔초      안선옥   5   3.0
# 23   관산초병설유      송이현   5   NaN
# 24     광주가족  강은숙 김장수  20   NaN
# 25     광주가족  강수진 이신선  20   NaN
# 26     광주가족   강갑연(?)  30   NaN
# 27      교육부      장경훈   5   NaN
# 28    군포수리초      정명숙   5   NaN
# ...

# %%
DataFrame(seokSchool)
# Out:
#       구분   소속           이름  금액   코드
# 239    7  학현초          최종철   5  3.0
# 240   50  학현초          김승희   5  3.0
# 241  119  학현초          김소희   5  3.0
# 242  120  학현초          안태우   5  3.0
# 243  121  학현초          유수정   5  3.0
# 244  122  학현초          이민호   5  3.0
# 245  123  학현초          김정혜   5  3.0
# 246  124  학현초          윤승희   5  3.0
# 247  125  학현초          이정화   5  3.0
# 248  126  학현초          김문희   5  3.0
# 249  127  학현초          남현화   5  3.0
# 250  128  학현초          김인숙   5  3.0
# 251  129  학현초          행정실   5  3.0
# 252  130  학현초          우서경   5  3.0
# 253  131  학현초          류지영   5  3.0
# 254  132  학현초          정은홍   5  3.0
# 255  133  학현초          류창한   5  3.0
# 256  134  학현초          김정연   5  3.0
# 257  135  학현초          유정임   5  3.0
# 258  136  학현초          정나라   5  3.0
# 259  137  학현초          정현숙   5  3.0
# 260  138  학현초          이다영   5  3.0
# 261  139  학현초          김수연   5  3.0
# 262  210  학현초          이희두   3  3.0
# 263  211  학현초          이경란   3  3.0
# ...

# %%
type(seokSchool)
# Out:
# pandas.core.frame.DataFrame

# %%
df2 = seokSchool

# %%
df2.reindex(range(31))
# Out:
#     구분   소속   이름  금액  코드
# 0  NaN  NaN  NaN NaN NaN
# 1  NaN  NaN  NaN NaN NaN
# 2  NaN  NaN  NaN NaN NaN
# 3  NaN  NaN  NaN NaN NaN
# 4  NaN  NaN  NaN NaN NaN
# 5  NaN  NaN  NaN NaN NaN
# 6  NaN  NaN  NaN NaN NaN
# 7  NaN  NaN  NaN NaN NaN
# 8  NaN  NaN  NaN NaN NaN
# 9  NaN  NaN  NaN NaN NaN
# 10 NaN  NaN  NaN NaN NaN
# 11 NaN  NaN  NaN NaN NaN
# 12 NaN  NaN  NaN NaN NaN
# 13 NaN  NaN  NaN NaN NaN
# 14 NaN  NaN  NaN NaN NaN
# 15 NaN  NaN  NaN NaN NaN
# 16 NaN  NaN  NaN NaN NaN
# 17 NaN  NaN  NaN NaN NaN
# 18 NaN  NaN  NaN NaN NaN
# 19 NaN  NaN  NaN NaN NaN
# 20 NaN  NaN  NaN NaN NaN
# 21 NaN  NaN  NaN NaN NaN
# 22 NaN  NaN  NaN NaN NaN
# 23 NaN  NaN  NaN NaN NaN
# 24 NaN  NaN  NaN NaN NaN
# 25 NaN  NaN  NaN NaN NaN
# 26 NaN  NaN  NaN NaN NaN
# 27 NaN  NaN  NaN NaN NaN
# 28 NaN  NaN  NaN NaN NaN
# 29 NaN  NaN  NaN NaN NaN
# 30 NaN  NaN  NaN NaN NaN

# %%
df2 = df

# %%
df2 = df2[['소속', '이름', '금액'] ]

# %%
df.loc[df2['소속'].isin( ['학현초','인교 미술95'] )]
# Out:
#       구분       소속           이름  금액   코드
# 173  140  인교 미술95          김민석   5  3.0
# 174  141  인교 미술95          류재현   5  3.0
# 175  142  인교 미술95          박귀선   5  3.0
# 176  144  인교 미술95          최준성   5  3.0
# 177  278  인교 미술95          안재원  10  3.0
# 239    7      학현초          최종철   5  3.0
# 240   50      학현초          김승희   5  3.0
# 241  119      학현초          김소희   5  3.0
# 242  120      학현초          안태우   5  3.0
# 243  121      학현초          유수정   5  3.0
# 244  122      학현초          이민호   5  3.0
# 245  123      학현초          김정혜   5  3.0
# 246  124      학현초          윤승희   5  3.0
# 247  125      학현초          이정화   5  3.0
# 248  126      학현초          김문희   5  3.0
# 249  127      학현초          남현화   5  3.0
# 250  128      학현초          김인숙   5  3.0
# 251  129      학현초          행정실   5  3.0
# 252  130      학현초          우서경   5  3.0
# 253  131      학현초          류지영   5  3.0
# 254  132      학현초          정은홍   5  3.0
# 255  133      학현초          류창한   5  3.0
# ...

# %%
df2_hak = df2.loc[df2['소속'].isin( ['학현초'] )]

# %%
df2_hak.sort_values('이름')
# Out:
#       소속           이름  금액
# 248  학현초          김문희   5
# 241  학현초          김소희   5
# 261  학현초          김수연   5
# 240  학현초          김승희   5
# 268  학현초  김을랑 박은실 최영미  10
# 250  학현초          김인숙   5
# 256  학현초          김정연   5
# 245  학현초          김정혜   5
# 265  학현초          김제화   3
# 249  학현초          남현화   5
# 253  학현초          류지영   5
# 255  학현초          류창한   5
# 264  학현초          박현경   3
# 267  학현초          신지원   3
# 242  학현초          안태우   5
# 252  학현초          우서경   5
# 243  학현초          유수정   5
# 257  학현초          유정임   5
# 246  학현초          윤승희   5
# 263  학현초          이경란   3
# 260  학현초          이다영   5
# 266  학현초          이미리   3
# 244  학현초          이민호   5
# 247  학현초          이정화   5
# 262  학현초          이희두   3
# 258  학현초          정나라   5
# 254  학현초          정은홍   5
# 259  학현초          정현숙   5
# 239  학현초          최종철   5
# 269  학현초          친목회  20
# 251  학현초          행정실   5

# %%
df2_hak['이름'].count()
# Out:
# 31

# %%
df_seok = df[ df[ '코드'] ==  3]

# %%
df_seok = df_seok[['소속', '이름', '금액','코드']]

# %%
df_seok.sort_values(by=['소속', '이름'], inplace=True)
# Out:
# /Users/mac/.virtualenvs/studyPython from 2018/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
df_seokSms = df_seok[df_seok['소속'] != '학현초']

# %%
df_seokSms = df_seokSms[df_seokSms['소속'] != '인교 미술95']

# %%
df_seokSms = df_seokSms[ ['소속', '이름']]

# %%
df_seokSms.to_csv('lawFatherSeokSms.csv')

# %%
dfTest = df_seokSms

# %%
dfTest.count()
# Out:
# 소속    22
# 이름    22
# dtype: int64

# %%
dfTest = dfTest.reindex(['소속', '이름', '전화번호'], axis=1)

# %%
df_seokSms = dfTest

# %%
df_seokSms.to_excel('lawFatherSeokSms.xlsx')
